# %% [markdown]
# # Homework 3

# %% [markdown]
# **Problem 1:** (4/10)
# (1) Create a pandas DataFrame from the following data:
#
#
#
# ```
# data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#         'Age': [25, 30, 22, 28],
#         'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}
# ```
#
# Display the resulting DataFrame.
#
# (2) Sort the DataFrame created in task (1) by 'Age' in ascending order. Display the sorted DataFrame.
#
# (3) Add a new column 'Country' to the DataFrame created in task (1). The 'Country' column should contain the values 'USA' for all rows. Display the updated DataFrame.
#
# (4) Create a new DataFrame that only contains rows where the 'Age' is greater than 25. Display this filtered DataFrame.
#
# (5) Export the DataFrame from task (4) to a CSV file named 'filtered_data.csv'.
#
# (6) Create a new DataFrame with the following data:
#
#
#
# ```
# more_data = {'Name': ['Eve', 'Frank'],
#              'Age': [24, 32],
#              'City': ['Miami', 'Dallas'],
#              'Country': ['USA', 'USA']}
#
# ```
# (7) Concatenate this new DataFrame with the one created in task (3) to create a combined DataFrame. Display the combined DataFrame.

# %%
#(1)
import pandas as pd

df = pd.DataFrame({"Name":["Alice","Bob","Charlie","David"], "Age":[25, 30, 22, 28], "City": ["New York", "Los Angeles", "Chicago", "Houston"]})
display(df)

#(2)
sorted_df = pd.DataFrame({"Name": ["Charlie", "Alice","David", "Bob"], "Age": [22, 25, 28, 30], "City": ["Chicago", "New York", "Houston", "Los Angeles"]})
display(sorted_df)

#(3)
added_column_df = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie", "David"], "Age": [25, 30, 22, 28], "City": ["New York", "Los Angeles", "Chicago", "Houston"], "Country": ["USA", "USA", "USA", "USA"]})
display(added_column_df)

#(4)
age_greater_than_25_df = pd.DataFrame({"Name":["Bob","David"], "Age": [30,28], "City": ["Los Angeles", "Houston"], "Country": ["USA", "USA"] })
display(age_greater_than_25_df)

#(5)
age_greater_than_25_df.to_csv("filtered_data.csv")

#(6)
more_data_df = pd.DataFrame({"Name": ["Eve", "Frank"], "Age": [24, 32], "City": ["Miami", "Dallas"], "Country": ["USA", "USA"]})
display(more_data_df)

#(7)
df1 = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie", "David"], "Age": [25,30,22,28], "City": ["New York", "Los Angeles", "Chicago", "Houston"], "Country": ["USA", "USA", "USA", "USA"]}, index = ["row 1", "row 2", "row 3", "row 4"])

df2 = pd.DataFrame ({"Name": ["Eve", "Frank"], "Age": [24, 32], "City": ["Miami", "Dallas"], "Country": ["USA", "USA"]}, index = ["row 5", "row 6"])

res = pd.concat([df1, df2])
display(res)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   28      Houston
#       Name  Age         City
# 0  Charlie   22      Chicago
# 1    Alice   25     New York
# 2    David   28      Houston
# 3      Bob   30  Los Angeles
#       Name  Age         City Country
# 0    Alice   25     New York     USA
# 1      Bob   30  Los Angeles     USA
# 2  Charlie   22      Chicago     USA
# 3    David   28      Houston     USA
#     Name  Age         City Country
# 0    Bob   30  Los Angeles     USA
# 1  David   28      Houston     USA
#     Name  Age    City Country
# 0    Eve   24   Miami     USA
# 1  Frank   32  Dallas     USA
#           Name  Age         City Country
# row 1    Alice   25     New York     USA
# row 2      Bob   30  Los Angeles     USA
# row 3  Charlie   22      Chicago     USA
# row 4    David   28      Houston     USA
# row 5      Eve   24        Miami     USA
# ...

# %% [markdown]
# **Problem 2:** (6/10)
# A vehicle moves along a straight path, and its velocity as a function of time is given by a polynomial equation. The objective is to analyze the vehicle's motion by:
#
# 1. **Creating a function** that takes a velocity function (as a sympy expression) and a time interval \([t_i, t_f]\), and plots the velocity and acceleration of the vehicle over the given time interval.
#
# **Steps to Follow:**
# 1. Define a function `plot_velocity_and_acceleration(velocity_function, ti, tf)` where `velocity_function` is a sympy expression of velocity as a function of time \(t\), `ti` is the initial time, and `tf` is the final time.
#
# 2. Inside the function, calculate the acceleration by differentiating the velocity function with respect to time.
#
# 3. Use matplotlib to plot both the velocity and acceleration functions over the interval \([t_i, t_f]\).

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

def plot_velocity_and_acceleration(velocity_function, ti, tf):
  time_elapsed = tf - ti
  derivative = sp.diff(velocity_function)
  solution = derivative.subs(t,time_elapsed)
  display(solution)

  velocity_ti = velocity_function.subs(t, ti)
  velocity_tf = velocity_function.subs (t, tf)
  velocity = (velocity_ti, velocity_tf)

  acceleration_ti = solution.subs(t, ti)
  acceleration_tf = solution.subs(t, tf)
  acceleration = (acceleration_ti, acceleration_tf)

  plt.plot((ti,tf),velocity, label = "Velocity")
  plt.plot ((ti, tf), acceleration, label = "Acceleration")
  plt.xlabel("Time")
  plt.ylabel("Velocity | Acceleration")
  plt.title("Velocity vs. Time | Acceleration vs. Time")
  plt.legend()
  plt.show()

### Testing, do not change below.
t = sp.symbols('t')
velocity_function = 5*t**2 + 1
ti = 0  # Initial time
tf = 2  # Final time

plot_velocity_and_acceleration(velocity_function, ti, tf)
# Out:
# 20
