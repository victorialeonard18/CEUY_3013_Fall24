# %% [markdown]
# 1. Find the data types for the following:

# %%
a=2
b=2.5
c="I love Python"

# %% [markdown]
# 2. Change b to integer and print out.

# %%
b=2.5

# %% [markdown]
# 3. Simple calculation:  do the operation "+","-","*","/" on a and b, print out the result of each operation.

# %%
a=100
b=20

# %% [markdown]
# 4. Print out "'a' with two decimals is 1.23" but use code to change 1.234567 to 2 decimals.

# %%
a=1.234567

# %% [markdown]
# 5. Find the length of the string "I am a NYU student", and use code to change the string to all lower case and print both out.

# %%
str_="I am a NYU student"

# %% [markdown]
# 6. Create a variable called `product` that contains the result of multiplying the float value of `float_1` and `float_2`.
#
# Then create a string called `final_string` that says:
#
# `The product was X`  (In which the X is the product of 0.25*40)

# %%
float_1 = 0.25
float_2 = "40"

print(final_string)
